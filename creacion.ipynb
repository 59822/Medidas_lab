# %%
import numpy as np
import pandas as pd

# %%
random = np.random.uniform(0.52,0.575,40)
file = pd.DataFrame({'Diametro':random})
#data_frame.head()

#Promedio 
promedio = file['Diametro'].mean()
promedio_redondeado = round(promedio,3)
median = file['Diametro'].median()
desviacion_estandar = np.std(file['Diametro'])
desv_red = round(desviacion_estandar,3)

print(desv_red)
# Out:
# 0.016

# %%
file.describe()
# Out:
#         Diametro
# count  40.000000
# mean    0.551806
# std     0.015819
# min     0.520411
# 25%     0.537462
# 50%     0.553811
# 75%     0.563902
# max     0.574753

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")

plt.figure(figsize=(2, 5))
sns.histplot(file['Diametro'], bins=20, kde=True, color='skyblue', edgecolor='black')
plt.title('Histograma de Diametro de Arverjas', fontsize=16)
plt.xlabel('Diametro', fontsize=14)
plt.ylabel('Frecuencia', fontsize=14)
plt.axvline(promedio, color='red', linestyle='dashed', linewidth=1)
plt.text(promedio + 0.01, plt.ylim()[1] * 0.9, f'Media: {promedio_redondeado}', color='red')
plt.axvline(promedio + desviacion_estandar, color='green', linestyle='dashed', linewidth=1)
plt.axvline(promedio - desviacion_estandar, color='green', linestyle='dashed', linewidth=1)
plt.text(promedio + desviacion_estandar + 0.01, plt.ylim()[1] * 0.8, f'+1σ: {desv_red}', color='green')
plt.text(promedio - desviacion_estandar - 0.1, plt.ylim()[1] * 0.8, f'-1σ: {desv_red}', color='green')
plt.grid(True)
plt.show()

# %%
sns.set(style="whitegrid");
plt.figure(figsize=(30, 6));
sns.boxplot(x = file['Diametro'], data=file);
plt.grid(True);
plt.show;

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class LinearRegresion(nn.Module):
    def __init__(self):
        super().__init__()
        Linear = self.Linear(1,1)

    def forward(self, x):
        return self.Linear(x)

n_l = 0.01
model = LinearRegresion()
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = n_l)

n_iters = 1000
x = torch.tensor(file['Diametro'].values)
for epoch in range(n_iters):
    y_predict = model(x)
    loss = criterion(y_predict, y)
# Out:
# c:\Users\estudiante\Downloads\laboratorio\.venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:295: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
